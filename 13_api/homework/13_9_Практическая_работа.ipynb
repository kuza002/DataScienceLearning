# %% [markdown]
# # Получение данных с помощью API. Домашнее задание
#
# В домашнем задании есть обязательные и дополнительные задачи.
#
# *Обязательные задачи* нужно сделать, чтобы проверить, что вы действительно усвоили материал модуля. Они обязательны к загрузке на проверку преподавателю.
#
# *Дополнительные задачи* для тех, кто чувствует, что нужно ещё немного потренироваться работе с Git. Вы также можете загрузить их на проверку преподавателю и получить по ним обратную связь.
#
# Удачи!

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Цели домашнего задания:**
# 1. Научиться выполнять HTTP-запросы с использованием библиотеки Requests.
# 2. Научиться сохранять данные из датафрейма в файлы xlsx и csv.
# 3. Научиться работать c Git и сохранять результаты своей работы в GitLab.

# %% [markdown]
# **Что входит в домашнее задание:**
# 1. *Обязательные задачи*:
#
# - две задачи на работу с Git,
# - две задачи на работу с бибилотекой Requests,
# - одна задача на сохранение данных из датафрейма в файлы.
#
# 2. *Дополнительные задачи*:
#
# - две задачи на закрепление работы с запросами,
# - одна задача на закрепление работы с Git.

# %% [markdown]
# **Критерии оценки:**
# - программа выдаёт верный ответ на заданном наборе данных;
# - код читабелен: переменным даны осмысленные названия, отступы и правила расстановки пробелов соблюдены;
# - репозиторий проекта содержит осмысленные коммиты, содержащие конкретные реализованные фичи, ветки названы согласно назначению, лишние файлы не хранятся в репозитории;
# - в репозитории проекта соблюдена иерархия директорий согласно списку модулей и содержащихся в них уроках;
# - репозиторий проекта содержит файлы с данными, полученными в результате выполнения домашнего задания.

# %% [markdown]
# **Как отправить задание на проверку**
#
# Сдайте домашние работы этого модуля через систему контроля версий Git сервиса Skillbox Gitlab. После загрузки работы на проверку необходимо сообщить об этом в LMS своему проверяющему преподавателю.

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# **Обязательные задачи**

# %% [markdown]
# Вы продолжите работать с iTunes Search API, чтобы познакомиться поближе с [Луи Армстронгом](https://ru.wikipedia.org/wiki/%D0%90%D1%80%D0%BC%D1%81%D1%82%D1%80%D0%BE%D0%BD%D0%B3,_%D0%9B%D1%83%D0%B8). Для этого вам нужно будет изучить документацию к [iTunes Search API](https://developer.apple.com/library/archive/documentation/AudioVideo/Conceptual/iTuneSearchAPI/Searching.html#//apple_ref/doc/uid/TP40017632-CH5-SW1) и выполнить задания.
#
# Репозиторий проекта располагается по адресу https://gitlab.skillbox.ru/LOGIN/ds-intro, где LOGIN — ваш логин в системе.

# %%
import requests
import pandas as pd

# %% [markdown]
# ***Задача 1***
#
# 1. С помощью `git clone` по SSH скопируйте на свой компьютер репозиторий `ds-intro.git`, если это не было сделано ранее.
# Если репозиторий уже скачан, обновите его состояние до актуальной версии с помощью `git pull`.
#
# 2. Перейдите в директорию `13_api/homework` и откройте ноутбук для выполнения домашнего задания.
#
# 3. Создайте ветку `homework_13` с помощью `git branch` и перейдите в неё. Далее работа должна продолжаться в новой ветке.
#
# **_Советы и рекомендации_**
#
# В дальнейшем, когда вы будете создавать новые ветки и работать с Git в этом и других модулях, придерживайтесь шаблона наименования веток:
# - `homework_module` для домашнего задания к модулю с номером `module`;
# - `practice_module` для практических заданий к модулю с номером `module`.

# %% [markdown]
# **Задача 2**
#
# 1. Выполните GET-запрос https://itunes.apple.com/lookup?id=518462 и распечатайте ответ в формате json.

# %%
url = 'https://itunes.apple.com/lookup'
params = {'id': 518462}
response = requests.get(url, params)

data = response.json()
print(data)
# Out:
# {'resultCount': 1, 'results': [{'wrapperType': 'artist', 'artistType': 'Artist', 'artistName': 'Louis Armstrong', 'artistLinkUrl': 'https://music.apple.com/us/artist/louis-armstrong/518462?uo=4', 'artistId': 518462, 'amgArtistId': 52456, 'primaryGenreName': 'Jazz', 'primaryGenreId': 11}]}

# %% [markdown]
# 2. Распечатайте код ответа.

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# 3. Распечатайте строку запроса.
#
#     _Подсказка:_ строку запроса можно распечатать с помощью метода `url`.

# %%
response.url
# Out:
# 'https://itunes.apple.com/lookup?id=518462'

# %% [markdown]
# 4. Сохраните в переменную `amg_artist_id` значение `amgArtistId` полученного ответа и распечатайте его.

# %%
# data = {
#  "resultCount":1,
#  "results": [
# {"wrapperType":"artist", "artistType":"Artist", "artistName":"Louis Armstrong", "artistLinkUrl":"https://music.apple.com/us/artist/louis-armstrong/518462?uo=4", "artistId":518462, "amgArtistId":52456, "primaryGenreName":"Jazz", "primaryGenreId":11}]
# }

amg_artist_id = data['results'][0]['amgArtistId']
print(amg_artist_id)
# Out:
# 52456

# %% [markdown]
# ***Задача 3***
#
# 1. Выполните POST-запрос к к ресурсу `lookup`, чтобы найти первые 100 записей, содержащих альбомы для артиста с `amgArtistId`, равного  полученному ранее `amg_artist_id`. Укажите время ожидания запроса 60 секунд и распечатайте ответ в формате json.

# %%
data = {'amgArtistId': 52456, 'entity': 'album', 'limit': 100}

response = requests.post('https://itunes.apple.com/lookup', data=data, timeout=60)

data = response.json()
print(data)
# Out:
# {'resultCount': 101, 'results': [{'wrapperType': 'artist', 'artistType': 'Artist', 'artistName': 'Louis Armstrong', 'artistLinkUrl': 'https://music.apple.com/us/artist/louis-armstrong/518462?uo=4', 'artistId': 518462, 'amgArtistId': 52456, 'primaryGenreName': 'Jazz', 'primaryGenreId': 11}, {'wrapperType': 'collection', 'collectionType': 'Album', 'artistId': 518462, 'collectionId': 1434914801, 'amgArtistId': 52456, 'artistName': 'Louis Armstrong', 'collectionName': 'All Time Greatest Hits', 'collectionCensoredName': 'All Time Greatest Hits', 'artistViewUrl': 'https://music.apple.com/us/artist/louis-armstrong/518462?uo=4', 'collectionViewUrl': 'https://music.apple.com/us/album/all-time-greatest-hits/1434914801?uo=4', 'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music126/v4/3f/78/d3/3f78d30d-1c44-4c8f-9481-a31430f525df/06UMGIM02666.rgb.jpg/60x60bb.jpg', 'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music126/v4/3f/78/d3/3f78d30d-1c44-4c8f-9481-a31430f525df/06UMGIM02666.rgb.jpg/100x100bb.jpg', 'collectionPrice': 9.99, 'collectionExplicitness': 'notExplicit', 'trackCount': 18, 'copyright': 'A Geffen Records Release; This Compilation ℗ 1994 UMG Recordings, Inc.', 'country': 'USA', 'currency': 'USD', 'releaseDate': '1994-01-01T08:00:00Z', 'primaryGenreName': 'Pop'}, {'wrapperType': 'collection', 'collectionType': 'Album', 'artistId': 518462, 'collectionId': 193896088, 'amgArtistId': 52456, 'artistName': 'Louis Armstrong', 'collectionName': 'The Essential Louis Armstrong', 'collectionCensoredName': 'The Essential Louis Armstrong', 'artistViewUrl': 'https://music.apple.com/us/artist/louis-armstrong/518462?uo=4', 'collectionViewUrl': 'https://music.apple.com/us/album/the-essential-louis-armstrong/193896088?uo=4', 'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music/c1/d1/00/mzi.scvunyuo.jpg/60x60bb.jpg', 'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music/c1/d1/00/mzi.scvunyuo.jpg/100x100bb.jpg', 'collectionPrice': 14.99, 'collectionExplicitness': 'notExplicit', 'trackCount': 37, 'copyright': '℗ Recorded Prior To 1972. All Rights Reserved by BMG Music, Originally Released 1925-1931, 1954, 1955, 1957, 2004 Sony Music Entertainment Inc.', 'country': 'USA', 'currency': 'USD', 'releaseDate': '1979-12-28T08:00:00Z', 'primaryGenreName': 'Jazz'}, {'wrapperType': 'collection', 'collectionType': 'Album', 'artistId': 518462, 'collectionId': 201274363, 'amgArtistId': 52456, 'artistName': 'Louis Armstrong', 'collectionName': 'The Best of the Hot 5 & Hot 7 Recordings', 'collectionCensoredName': 'The Best of the Hot 5 & Hot 7 Recordings', 'artistViewUrl': 'https://music.apple.com/us/artist/louis-armstrong/518462?uo=4', 'collectionViewUrl': 'https://music.apple.com/us/album/the-best-of-the-hot-5-hot-7-recordings/201274363?uo=4', 'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/54/10/9d/mzi.tzqujtgu.jpg/60x60bb.jpg', 'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/54/10/9d/mzi.tzqujtgu.jpg/100x100bb.jpg', 'collectionPrice': 9.99, 'collectionExplicitness': 'notExplicit', 'trackCount': 18, 'copyright': '℗ Originally Released 1926, 1927, 1928, 1929, 1940, (P) 2002 Sony Music Entertainment Inc.', 'country': 'USA', 'currency': 'USD', 'releaseDate': '2002-07-30T07:00:00Z', 'primaryGenreName': 'Jazz'}, {'wrapperType': 'collection', 'collectionType': 'Album', 'artistId': 73568, 'collectionId': 1445666702, 'amgArtistId': 6503, 'artistName': 'Ella Fitzgerald & Louis Armstrong', 'collectionName': 'Ella & Louis Christmas', 'collectionCensoredName': 'Ella & Louis Christmas', 'artistViewUrl': 'https://music.apple.com/us/artist/ella-fitzgerald/73568?uo=4', 'collectionViewUrl': 'https://music.apple.com/us/album/ella-louis-christmas/1445666702?uo=4', 'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music115/v4/16/a2/75/16a27533-9fc4-843b-c8d3-d81a377a2395/16UMGIM78399.rgb.jpg/60x60bb.jpg', 'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music115/v4/16/a2/75/16a27533-9fc ...

# %% [markdown]
# 2. Выведите количество записей в ответе.

# %%
print(data['resultCount'])
# Out:
# 101

# %% [markdown]
# 3. Посмотрите внимательно на список с записями и обратите внимание, что мы запрашивали 100 альбомов, то есть на одну запись меньше, чем нам показал счётчик.
# **Ответьте, в чём причина:** _Потому, что первым словарём в списке выступает запись о самом артисте_

# %% [markdown]
# ***Задача 4***
#
# 1. С учётом ответа на предыдущий вопрос разделите список на два списка:
# - `data1` — альбомы с 1 по 30,
# - `data2` — оставшиеся альбомы.
#
#     Распечатайте количество элементов в каждом списке.

# %%
data1 = data['results'][1:31]
print(len(data1))

data2 = data['results'][31:]
print(len(data1))
# Out:
# 30
# 30

# %% [markdown]
# 2. Создайте датафрейм `df1` на основе списка `data1` и распечатайте его, а затем запишите его на лист `albums` в файл `30_albums.xlsx` в директории проекта `13_api/homework/data`. Не забудьте перед этим создать нужную директорию.

# %%
df = pd.DataFrame(data1)
df.to_excel('data/30_albums.xlsx', sheet_name='albums')
df
# Out:
#    wrapperType collectionType  artistId  collectionId  amgArtistId
# 0   collection          Album    518462    1434914801        52456  \
# 1   collection          Album    518462     193896088        52456
# 2   collection          Album    518462     201274363        52456
# 3   collection          Album     73568    1445666702         6503
# 4   collection          Album     73568    1431066643         6503
# 5   collection          Album    518462    1425235202        52456
# 6   collection          Album    518462     696523069        52456
# 7   collection          Album     73568    1469584174         6503
# 8   collection          Album    518462     158691605        52456
# 9   collection          Album    518462    1440787250        52456
# 10  collection          Album    518462    1644157235        52456
# 11  collection          Album     73568    1454734940         6503
# 12  collection          Album    518462     516685592        52456
# 13  collection          Album    518462    1440749171        52456
# 14  collection          Album    518462     477023849        52456
# 15  collection          Album     73568    1359340014         6503
# 16  collection          Album    518462    1425244065        52456
# 17  collection          Album    518462     695988623        52456
# 18  collection          Album    518462     186308940        52456
# 19  collection          Album     25687     716211198         3094
# 20  collection          Album    518462    1425262446        52456
# 21  collection          Album    405220     194021777         6746
# 22  collection          Album    518462     200036163        52456
# 23  collection          Album    518462    1434925400        52456
# 24  collection          Album    518462     171086591        52456
# 25  collection          Album    518462     293785416        52456
# 26  collection          Album    518462     157407490        52456
# 27  collection          Album    518462     157384070        52456
# 28  collection          Album    518462     158662145        52456
# 29  collection          Album    518462     293785410        52456
#
#                                        artistName
# 0                                 Louis Armstrong  \
# 1                                 Louis Armstrong
# 2                                 Louis Armstrong
# 3               Ella Fitzgerald & Louis Armstrong
# 4               Ella Fitzgerald & Louis Armstrong
# 5                                 Louis Armstrong
# 6                Louis Armstrong & Duke Ellington
# 7               Ella Fitzgerald & Louis Armstrong
# 8               Louis Armstrong and His All-Stars
# 9                                 Louis Armstrong
# 10                                Louis Armstrong
# 11              Ella Fitzgerald & Louis Armstrong
# 12  Louis Armstrong, Tyree Glenn & Tommy Gwaltney
# 13                                Louis Armstrong
# 14                                Louis Armstrong
# 15              Ella Fitzgerald & Louis Armstrong
# 16              Louis Armstrong & Ella Fitzgerald
# 17               Louis Armstrong & Duke Ellington
# 18                                Louis Armstrong
# 19                  Bing Crosby & Louis Armstrong
# 20               Louis Armstrong & Oscar Peterson
# 21                   Louis Armstrong & Earl Hines
# 22                                Louis Armstrong
# 23                                Louis Armstrong
# 24                                Louis Armstrong
# 25                                Louis Armstrong
# 26              Louis Armstrong and His All-Stars
# 27                                Louis Armstrong
# 28                                Louis Armstrong
# 29                                Louis Armstrong
#
#                                        collectionName
# 0                              All Time Greatest Hits  \
# 1                       The Essential Louis Armstrong
# 2            The Best of the Hot 5 & Hot 7 Recordings
# 3                              Ella & Louis Christmas
# 4   The Best Of Ella Fitzgerald And Louis Armstron...
# 5   20th Century Masters: The Best of Louis Armstr...
# 6     The Great Summit: The Master Tapes (Remastered)
# 7                                      Ella and Louis
# 8                    Louis Armstrong Plays W.C. Handy
# 9                              What a Wonderful World
# 10                       Louis Wishes You a Cool Yule
# 11                            Ella & Louis for Lovers
# 12  Satchmo at the National Press Club - Red Beans...
# 13                       Disney Songs the Satchmo Way
# 14       The Complete Hot Five & Hot Seven Recordings
# 15       Cheek To Cheek: The Complete Duet Recordings
# 16                                     Porgy and Bess
# 17  The Great Summit: Complete Sessions (Deluxe Ed...
# 18                    Ken Burns Jazz: Louis Armstrong
# 19                                     Bing & Satchmo
# 20  Louis Armstrong Meets Oscar Peterson (Expanded...
# 21  Louis Armstrong, Vol. 4 - Louis Armstrong and ...
# 22                              Satch Blows the Blues
# 23           The Ultimate Collection: Louis Armstrong
# 24          The Great Chicago Concert 1956 - Complete
# 25  The Complete Hot Five and Hot Seven Recordings...
# 26             Ambassador Satch (Live in Europe 1955)
# 27                                         Super Hits
# 28                     The Essence of Louis Armstrong
# 29  The Complete Hot Five and Hot Seven Recordings...
#
#                                collectionCensoredName
# 0                              All Time Greatest Hits  \
# 1                       The Essential Louis Armstrong
# 2            The Best of the Hot 5 & Hot 7 Recordings
# 3                              Ella & Louis Christmas
# 4   The Best Of Ella Fitzgerald And Louis Armstron...
# 5   20th Century Masters: The Best of Louis Armstr...
# 6     The Great Summit: The Master Tapes (Remastered)
# 7                                      Ella and Louis
# 8                    Louis Armstrong Plays W.C. Handy
# 9                              What a Wonderful World
# 10                       Louis Wishes You a Cool Yule
# 11                            Ella & Louis for Lovers
# 12  Satchmo at the National Press Club - Red Beans...
# 13                       Disney Songs the Satchmo Way
# 14       The Complete Hot Five & Hot Seven Recordings
# 15       Cheek To Cheek: The Complete Duet Recordings
# 16                                     Porgy and Bess
# 17  The Great Summit: Complete Sessions (Deluxe Ed...
# 18                    Ken Burns Jazz: Louis Armstrong
# 19                                     Bing & Satchmo
# 20  Louis Armstrong Meets Oscar Peterson (Expanded...
# 21  Louis Armstrong, Vol. 4 - Louis Armstrong and ...
# 22                              Satch Blows the Blues
# 23           The Ultimate Collection: Louis Armstrong
# 24          The Great Chicago Concert 1956 - Complete
# 25  The Complete Hot Five and Hot Seven Recordings...
# 26             Ambassador Satch (Live in Europe 1955)
# 27                                         Super Hits
# 28                     The Essence of Louis Armstrong
# 29  The Complete Hot Five and Hot Seven Recordings...
#
#                                         artistViewUrl
# 0   https://music.apple.com/us/artist/louis-armstr...  \
# 1   https://music.apple.com/us/artist/louis-armstr...
# 2   https://music.apple.com/us/artist/louis-armstr...
# 3   https://music.apple.com/us/artist/ella-fitzger...
# 4   https://music.apple.com/us/artist/ella-fitzger...
# 5   https://music.apple.com/us/artist/louis-armstr...
# 6   https://music.apple.com/us/artist/louis-armstr...
# 7   https://music.apple.com/us/artist/ella-fitzger...
# 8   https://music.apple.com/us/artist/louis-armstr...
# 9   https://music.apple.com/us/artist/louis-armstr...
# 10  https://music.apple.com/us/artist/louis-armstr...
# 11  https://music.apple.com/us/artist/ella-fitzger...
# 12  https://music.apple.com/us/artist/louis-armstr...
# 13  https://music.apple.com/us/artist/louis-armstr...
# 14  https://music.apple.com/us/artist/louis-armstr...
# 15  https://music.apple.com/us/artist/ella-fitzger...
# 16  https://music.apple.com/us/artist/louis-armstr...
# 17  https://music.apple.com/us/artist/louis-armstr...
# 18  https://music.apple.com/us/artist/louis-armstr...
# 19  https://music.apple.com/us/artist/bing-crosby/...
# 20  https://music.apple.com/us/artist/louis-armstr...
# 21  https://music.apple.com/us/artist/earl-fatha-h...
# 22  https://music.apple.com/us/artist/louis-armstr...
# 23  https://music.apple.com/us/artist/louis-armstr...
# 24  https://music.apple.com/us/artist/louis-armstr...
# 25  https://music.apple.com/us/artist/louis-armstr...
# 26  https://music.apple.com/us/artist/louis-armstr...
# 27  https://music.apple.com/us/artist/louis-armstr...
# 28  https://music.apple.com/us/artist/louis-armstr...
# 29  https://music.apple.com/us/artist/louis-armstr...
#
#                                     collectionViewUrl
# 0   https://music.apple.com/us/album/all-time-grea...  \
# 1   https://music.apple.com/us/album/the-essential...
# 2   https://music.apple.com/us/album/the-best-of-t...
# 3   https://music.apple.com/us/album/ella-louis-ch...
# 4   https://music.apple.com/us/album/the-best-of-e...
# 5   https://music.apple.com/us/album/20th-century-...
# 6   https://music.apple.com/us/album/the-great-sum...
# 7   https://music.apple.com/us/album/ella-and-loui...
# 8   https://music.apple.com/us/album/louis-armstro...
# 9   https://music.apple.com/us/album/what-a-wonder...
# 10  https://music.apple.com/us/album/louis-wishes-...
# 11  https://music.apple.com/us/album/ella-louis-fo...
# 12  https://music.apple.com/us/album/satchmo-at-th...
# 13  https://music.apple.com/us/album/disney-songs-...
# 14  https://music.apple.com/us/album/the-complete-...
# 15  https://music.apple.com/us/album/cheek-to-chee...
# 16  https://music.apple.com/us/album/porgy-and-bes...
# 17  https://music.apple.com/us/album/the-great-sum...
# 18  https://music.apple.com/us/album/ken-burns-jaz...
# 19  https://music.apple.com/us/album/bing-satchmo/...
# 20  https://music.apple.com/us/album/louis-armstro...
# 21  https://music.apple.com/us/album/louis-armstro...
# 22  https://music.apple.com/us/album/satch-blows-t...
# 23  https://music.apple.com/us/album/the-ultimate-...
# 24  https://music.apple.com/us/album/the-great-chi...
# 25  https://music.apple.com/us/album/the-complete-...
# 26  https://music.apple.com/us/album/ambassador-sa...
# 27  https://music.apple.com/us/album/super-hits/15...
# 28  https://music.apple.com/us/album/the-essence-o...
# 29  https://music.apple.com/us/album/the-complete-...
#
#                                          artworkUrl60
# 0   https://is3-ssl.mzstatic.com/image/thumb/Music...  \
# 1   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 2   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 3   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 4   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 5   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 6   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 7   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 8   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 9   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 10  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 11  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 12  https://is4-ssl.mzstatic.com/image/thumb/Featu...
# 13  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 14  https://is5-ssl.mzstatic.com/image/thumb/Featu...
# 15  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 16  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 17  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 18  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 19  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 20  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 21  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 22  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 23  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 24  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 25  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 26  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 27  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 28  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 29  https://is2-ssl.mzstatic.com/image/thumb/Music...
#
#                                         artworkUrl100  collectionPrice
# 0   https://is3-ssl.mzstatic.com/image/thumb/Music...             9.99  \
# 1   https://is4-ssl.mzstatic.com/image/thumb/Music...            14.99
# 2   https://is1-ssl.mzstatic.com/image/thumb/Music...             9.99
# 3   https://is4-ssl.mzstatic.com/image/thumb/Music...             9.99
# 4   https://is3-ssl.mzstatic.com/image/thumb/Music...             9.99
# 5   https://is1-ssl.mzstatic.com/image/thumb/Music...             6.99
# 6   https://is4-ssl.mzstatic.com/image/thumb/Music...             9.99
# 7   https://is3-ssl.mzstatic.com/image/thumb/Music...             9.99
# 8   https://is3-ssl.mzstatic.com/image/thumb/Music...             9.99
# 9   https://is3-ssl.mzstatic.com/image/thumb/Music...             9.99
# 10  https://is2-ssl.mzstatic.com/image/thumb/Music...            11.99
# 11  https://is3-ssl.mzstatic.com/image/thumb/Music...             9.99
# 12  https://is4-ssl.mzstatic.com/image/thumb/Featu...             9.99
# 13  https://is4-ssl.mzstatic.com/image/thumb/Music...             6.99
# 14  https://is5-ssl.mzstatic.com/image/thumb/Featu...            29.99
# 15  https://is1-ssl.mzstatic.com/image/thumb/Music...            39.99
# 16  https://is4-ssl.mzstatic.com/image/thumb/Music...             9.99
# 17  https://is4-ssl.mzstatic.com/image/thumb/Music...            12.99
# 18  https://is5-ssl.mzstatic.com/image/thumb/Music...             9.99
# 19  https://is4-ssl.mzstatic.com/image/thumb/Music...             9.99
# 20  https://is2-ssl.mzstatic.com/image/thumb/Music...             9.99
# 21  https://is2-ssl.mzstatic.com/image/thumb/Music...             9.99
# 22  https://is5-ssl.mzstatic.com/image/thumb/Music...             9.99
# 23  https://is1-ssl.mzstatic.com/image/thumb/Music...            27.99
# 24  https://is1-ssl.mzstatic.com/image/thumb/Music...            16.99
# 25  https://is5-ssl.mzstatic.com/image/thumb/Music...             9.99
# 26  https://is4-ssl.mzstatic.com/image/thumb/Music...             9.99
# 27  https://is4-ssl.mzstatic.com/image/thumb/Music...             5.99
# 28  https://is2-ssl.mzstatic.com/image/thumb/Music...             9.99
# 29  https://is2-ssl.mzstatic.com/image/thumb/Music...             9.99
#
#    collectionExplicitness  trackCount
# 0             notExplicit          18  \
# 1             notExplicit          37
# 2             notExplicit          18
# 3             notExplicit          20
# 4             notExplicit          15
# 5             notExplicit          10
# 6             notExplicit          17
# 7             notExplicit          11
# 8             notExplicit          16
# 9             notExplicit          11
# 10            notExplicit          11
# 11            notExplicit          11
# 12            notExplicit          11
# 13            notExplicit          10
# 14            notExplicit          93
# 15            notExplicit          75
# 16            notExplicit          15
# 17            notExplicit          27
# 18            notExplicit          25
# 19            notExplicit          12
# 20            notExplicit          16
# 21            notExplicit          18
# 22            notExplicit          16
# 23            notExplicit          59
# 24            notExplicit          26
# 25            notExplicit          22
# 26            notExplicit          13
# 27            notExplicit          10
# 28            notExplicit          12
# 29            notExplicit          22
#
#                                             copyright country currency
# 0   A Geffen Records Release; This Compilation ℗ 1...     USA      USD  \
# 1   ℗ Recorded Prior To 1972. All Rights Reserved ...     USA      USD
# 2   ℗ Originally Released 1926, 1927, 1928, 1929, ...     USA      USD
# 3   This Compilation ℗ 2016 The Verve Music Group,...     USA      USD
# 4   A Verve Label Group release; This Compilation ...     USA      USD
# 5   A Geffen Records Release; This Compilation ℗ 1...     USA      USD
# 6   ℗ 2000 Parlophone Records Ltd, a Warner Music ...     USA      USD
# 7   ℗ 2011 The Verve Music Group, a Division of UM...     USA      USD
# 8   ℗ Originally Released 1954 Sony Music Entertai...     USA      USD
# 9   This Compilation ℗ 1968 The Verve Music Group,...     USA      USD
# 10  A Verve Records release; This Compilation ℗ 20...     USA      USD
# 11  A Verve Label Group Release; This Compilation ...     USA      USD
# 12                                                NaN     USA      USD
# 13     ℗ 1996 Buena Vista Pictures Distribution, Inc.     USA      USD
# 14  ℗ Originally Released 1926, 1927 Courtesy of M...     USA      USD
# 15  A Verve Records release; ℗ 2018 UMG Recordings...     USA      USD
# 16  A Verve Label Group release; ℗ 1958 UMG Record...     USA      USD
# 17  ℗ 2000 Roulette Jazz (R) is a registered trade...     USA      USD
# 18  ℗ Compilation (P) 2000 SONY BMG MUSIC ENTERTAI...     USA      USD
# 19       This Compilation ℗ 2008 Capitol Records, LLC     USA      USD
# 20  ℗ 1985 The Verve Music Group, a Division of UM...     USA      USD
# 21  ℗ Originally Released 1928, 1929, 1941 SONY BM...     USA      USD
# 22  ℗ Originally Released 1928, 1929, 1930, 1931, ...     USA      USD
# 23  A Verve Records release; This Compilation ℗ 20...     USA      USD
# 24  ℗ Originally Recorded 1956, Originally Release...     USA      USD
# 25  ℗ Originally Released 1926, 1927, 1928, 1940, ...     USA      USD
# 26  ℗ Originally Recorded 1955, Originally Release...     USA      USD
# 27  ℗ Originally Released 1954,1957,1959,1967,1982...     USA      USD
# 28               ℗ 1991 Sony Music Entertainment Inc.     USA      USD
# 29  ℗ Originally Released 1928, 1929, 1940, (P) 20...     USA      USD
#
#              releaseDate primaryGenreName
# 0   1994-01-01T08:00:00Z              Pop
# 1   1979-12-28T08:00:00Z             Jazz
# 2   2002-07-30T07:00:00Z             Jazz
# 3   2016-11-25T08:00:00Z          Holiday
# 4   1997-08-20T07:00:00Z             Jazz
# 5   1999-03-16T08:00:00Z             Jazz
# 6   2001-01-08T08:00:00Z             Jazz
# 7   2011-01-01T08:00:00Z             Jazz
# 8   1997-03-03T08:00:00Z             Jazz
# 9   1968-01-01T08:00:00Z             Jazz
# 10  2022-10-28T07:00:00Z          Holiday
# 11  2005-06-06T07:00:00Z             Jazz
# 12  2012-04-24T07:00:00Z             Jazz
# 13  1996-01-01T08:00:00Z             Jazz
# 14  2006-09-19T07:00:00Z             Jazz
# 15  2018-04-06T07:00:00Z             Jazz
# 16  1958-01-01T08:00:00Z             Jazz
# 17  2000-07-06T07:00:00Z             Jazz
# 18  2000-11-03T08:00:00Z             Jazz
# 19  2008-01-01T08:00:00Z            Vocal
# 20  1957-10-14T08:00:00Z             Jazz
# 21  1989-08-18T07:00:00Z             Jazz
# 22  2002-07-26T07:00:00Z             Jazz
# 23  2000-07-25T07:00:00Z             Jazz
# 24  1997-04-29T07:00:00Z             Jazz
# 25  2003-04-11T07:00:00Z             Jazz
# 26  2000-06-07T07:00:00Z             Jazz
# 27  2000-01-07T08:00:00Z             Jazz
# 28  1991-10-11T07:00:00Z             Jazz
# 29  2003-04-11T07:00:00Z             Jazz

# %% [markdown]
# Для удобства переиспользования путь к папке с данными удобно вынести в отдельную переменную. Оставьте текущий путь в `path` или пропишите полный путь от директории, в которой запущен Jupyter Notebook.

# %%
path = 'data/'

# %% [markdown]
# 3. Создайте датафрейм `df2` на основе списка `data2` и распечатайте его, а затем запишите его в файл `70_albums.csv` в директории проекта `13_api/homework/data`, указав в качестве разделителя знак табуляции.

# %%
df2 = pd.DataFrame(data2)
df2.to_csv(path+"70_albums.csv", sep='\t')
df2
# Out:
#    wrapperType collectionType  artistId  collectionId  amgArtistId
# 0   collection          Album     73568    1445098984       6503.0  \
# 1   collection          Album    518462     158673207      52456.0
# 2   collection          Album    518462     193043791      52456.0
# 3   collection          Album    518462    1443885095      52456.0
# 4   collection          Album    518462     198154274      52456.0
# ..         ...            ...       ...           ...          ...
# 65  collection          Album    518462    1475524510      52456.0
# 66  collection          Album    518462    1466892492      52456.0
# 67  collection          Album    518462    1500084993      52456.0
# 68  collection          Album    518462    1444070460      52456.0
# 69  collection          Album     73568    1434904687       6503.0
#
#                            artistName
# 0   Ella Fitzgerald & Louis Armstrong  \
# 1                     Louis Armstrong
# 2                     Louis Armstrong
# 3                     Louis Armstrong
# 4                     Louis Armstrong
# ..                                ...
# 65                    Louis Armstrong
# 66                    Louis Armstrong
# 67                    Louis Armstrong
# 68                    Louis Armstrong
# 69  Ella Fitzgerald & Louis Armstrong
#
#                                        collectionName
# 0   20th Century Masters / The Millennium Collecti...  \
# 1            Louis Armstrong: 16 Most Requested Songs
# 2            The Hot Fives and Hot Sevens, Volume III
# 3                             Louis and The Good Book
# 4            The Hot Fives and Hot Sevens - Volume II
# ..                                                ...
# 65    Portrait of the Artist As a Young Man 1923-1934
# 66      Ain't Gonna Give Nobody None of My Jelly Roll
# 67                      The Essential Louis Armstrong
# 68                              Mack the Knife (Live)
# 69               The Complete Ella and Louis On Verve
#
#                                collectionCensoredName
# 0   20th Century Masters / The Millennium Collecti...  \
# 1            Louis Armstrong: 16 Most Requested Songs
# 2            The Hot Fives and Hot Sevens, Volume III
# 3                             Louis and The Good Book
# 4            The Hot Fives and Hot Sevens - Volume II
# ..                                                ...
# 65    Portrait of the Artist As a Young Man 1923-1934
# 66      Ain't Gonna Give Nobody None of My Jelly Roll
# 67                      The Essential Louis Armstrong
# 68                              Mack the Knife (Live)
# 69               The Complete Ella and Louis On Verve
#
#                                         artistViewUrl
# 0   https://music.apple.com/us/artist/ella-fitzger...  \
# 1   https://music.apple.com/us/artist/louis-armstr...
# 2   https://music.apple.com/us/artist/louis-armstr...
# 3   https://music.apple.com/us/artist/louis-armstr...
# 4   https://music.apple.com/us/artist/louis-armstr...
# ..                                                ...
# 65  https://music.apple.com/us/artist/louis-armstr...
# 66  https://music.apple.com/us/artist/louis-armstr...
# 67  https://music.apple.com/us/artist/louis-armstr...
# 68  https://music.apple.com/us/artist/louis-armstr...
# 69  https://music.apple.com/us/artist/ella-fitzger...
#
#                                     collectionViewUrl
# 0   https://music.apple.com/us/album/20th-century-...  \
# 1   https://music.apple.com/us/album/louis-armstro...
# 2   https://music.apple.com/us/album/the-hot-fives...
# 3   https://music.apple.com/us/album/louis-and-the...
# 4   https://music.apple.com/us/album/the-hot-fives...
# ..                                                ...
# 65  https://music.apple.com/us/album/portrait-of-t...
# 66  https://music.apple.com/us/album/aint-gonna-gi...
# 67  https://music.apple.com/us/album/the-essential...
# 68  https://music.apple.com/us/album/mack-the-knif...
# 69  https://music.apple.com/us/album/the-complete-...
#
#                                          artworkUrl60
# 0   https://is4-ssl.mzstatic.com/image/thumb/Music...  \
# 1   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 2   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 3   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 4   https://is1-ssl.mzstatic.com/image/thumb/Featu...
# ..                                                ...
# 65  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 66  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 67  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 68  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 69  https://is3-ssl.mzstatic.com/image/thumb/Music...
#
#                                         artworkUrl100  collectionPrice
# 0   https://is4-ssl.mzstatic.com/image/thumb/Music...             6.99  \
# 1   https://is5-ssl.mzstatic.com/image/thumb/Music...             9.99
# 2   https://is4-ssl.mzstatic.com/image/thumb/Music...             9.99
# 3   https://is1-ssl.mzstatic.com/image/thumb/Music...             9.99
# 4   https://is1-ssl.mzstatic.com/image/thumb/Featu...             9.99
# ..                                                ...              ...
# 65  https://is5-ssl.mzstatic.com/image/thumb/Music...            34.99
# 66  https://is3-ssl.mzstatic.com/image/thumb/Music...             9.99
# 67  https://is1-ssl.mzstatic.com/image/thumb/Music...             9.99
# 68  https://is4-ssl.mzstatic.com/image/thumb/Music...             9.99
# 69  https://is3-ssl.mzstatic.com/image/thumb/Music...            27.99
#
#    collectionExplicitness  trackCount
# 0             notExplicit          10  \
# 1             notExplicit          16
# 2             notExplicit          16
# 3             notExplicit          20
# 4             notExplicit          16
# ..                    ...         ...
# 65            notExplicit          81
# 66            notExplicit          12
# 67            notExplicit          16
# 68            notExplicit          11
# 69            notExplicit          47
#
#                                             copyright country currency
# 0   A Verve Label Group Release; This Compilation ...     USA      USD  \
# 1                ℗ 1994 Sony Music Entertainment Inc.     USA      USD
# 2                             ℗ 1989 CBS RECORDS INC.     USA      USD
# 3   ℗ 2001 The Verve Music Group, a Division of UM...     USA      USD
# 4   ℗ Originally Released 1926, 1927 SONY BMG MUSI...     USA      USD
# ..                                                ...     ...      ...
# 65  ℗ This compilation (P) 1994 Sony Music Enterta...     USA      USD
# 66  ℗ 1964 © Audio Fidelity™ a division of 43 Nort...     USA      USD
# 67  A Verve Label Group Release; This Compilation ...     USA      USD
# 68                               ℗ 1957 Pablo Records     USA      USD
# 69  A Verve Records Release; This Compilation ℗ 19...     USA      USD
#
#              releaseDate primaryGenreName
# 0   2007-06-12T07:00:00Z             Jazz
# 1   1994-05-27T07:00:00Z             Jazz
# 2   1989-03-24T08:00:00Z             Jazz
# 3   1958-01-01T08:00:00Z             Jazz
# 4   1988-08-30T07:00:00Z             Jazz
# ..                   ...              ...
# 65  1994-09-27T07:00:00Z             Jazz
# 66  1964-05-01T07:00:00Z        Dixieland
# 67  1992-10-20T07:00:00Z             Jazz
# 68  1957-01-01T08:00:00Z             Jazz
# 69  1997-05-20T07:00:00Z             Jazz
#
# [70 rows x 20 columns]

# %% [markdown]
# ***Задача 5***
#
# Пришло время сохранить наши изменения в GitLab.
#
# 1. Добавьте сделанные в папке проекта изменения с помощью `git add`.
#
# 2. Если у вас в добавленных файлах появились файлы настроек, не забудьте добавить их в файл `.gitignore`, чтобы репозиторий содержал только релевантные файлы (подробнее о том, как правильно добавлять файлы в `.gitignore` можно узнать по ссылке в блоке [Запись изменений в репозиторий: Игнорирование файлов](https://git-scm.com/book/ru/v2/%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B-Git-%D0%97%D0%B0%D0%BF%D0%B8%D1%81%D1%8C-%D0%B8%D0%B7%D0%BC%D0%B5%D0%BD%D0%B5%D0%BD%D0%B8%D0%B9-%D0%B2-%D1%80%D0%B5%D0%BF%D0%BE%D0%B7%D0%B8%D1%82%D0%BE%D1%80%D0%B8%D0%B9)).
#
# 3. Сохраните состояние проекта с помощью `git commit`, дайте тексту коммита осмысленное название.
#
# 4. Отправьте изменения на сервер GitLab с помощью `git push` в текущую ветку `homework_13`.
#
# 5. Зайдите в GitLab Skillbox и сделайте Merge Request включения текущей ветки в главную ветку `master`, указав в качестве адресата своего проверяющего преподавателя. Текущую ветку не удаляйте, она потребуется для проверки.
#
# _Напоминание:_ Не забудьте сохранить свои изменения в GitLab и после выполнения дополнительных задач 6 и 7.

# %% [markdown]
# **Дополнительные задачи**

# %% [markdown]
# ***Задача 6***
#
# Для ответа на вопрос **Задачи 3** напишите код, результат которого наглядно показывает отличие некоторых записей от остальных.

# %%
# Ваш код здесь

# %% [markdown]
# **Задача 7**
#
# Попробуйте сформировать запросы к [iTunes Search API](https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/) таким образом, чтобы получить статусы ответов, отличные от 200. Например, 400 и 404. Распечатайте коды статусов для каждого запроса.
#
# _Подсказка:_ воспользуйтесь [шпаргалкой по кодам ответа HTTP](https://developer.mozilla.org/ru/docs/Web/HTTP/Status), чтобы понять, как следует изменить запрос, чтобы сервер вернул определённую ошибку в ответе.

# %%
# Ваш код здесь

# %% [markdown]
# ***Задача 8***
#
# Загрузите результат выполнения практического задания после урока 5 в GitLab проекта в директорию `13_api/practice`.
#
# Для этого создайте ветку `practice_13`, скопируйте файлы практического задания в проект, загрузите изменения в созданную ветку в GitLab, а затем создайте MergeRequest без указания проверяющего и сами же примите собственный запрос.
